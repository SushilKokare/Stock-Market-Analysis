# %%
#2 Hammer ( Paper Umbrella ) of one stock before n days from today

def gethammer(df):
    bh={}    # blue hammer 
    rh={}    # red hammer

    if('OPEN' in df.columns):

        for ind in df.index:
            if(df['OPEN'][ind] < df['CLOSE'][ind] ):
                bper=((float(df['CLOSE'][ind])-float(df['OPEN'][ind]))/float(df['CLOSE'][ind]))*100 # body percentage
                us=((float(df['HIGH'][ind])-float(df['CLOSE'][ind]))/float(df['CLOSE'][ind]))*100  # Upper Shadow
                ls=((float(df['OPEN'][ind])-float(df['LOW'][ind]))/float(df['CLOSE'][ind]))*100  # Lower Shadow
                if(bper>=0.7 and bper<=2.3 and us<=0.8 and ls>=bper*1.8):
                    #print(df['SYMBOL'][ind] +"="+str(per) +" Per = "+str(per)+" US = "+str(us)+" LS = "+str(ls))
                    bh[df['SYMBOL'][ind]]= bper

            elif(df['CLOSE'][ind] < df['OPEN'][ind] ):
                bper=((float(df['OPEN'][ind])-float(df['CLOSE'][ind]))/float(df['CLOSE'][ind]))*100 # body percentage
                us=((float(df['HIGH'][ind])-float(df['OPEN'][ind]))/float(df['CLOSE'][ind]))*100  # Upper Shadow
                ls=((float(df['CLOSE'][ind])-float(df['LOW'][ind]))/float(df['CLOSE'][ind]))*100  # Lower Shadow
                if(bper>=0.7 and bper<=2.3 and us<=0.8 and ls>=bper*1.8):
                     #print(df['SYMBOL'][ind] +"="+str(per) +" Per = "+str(per)+" US = "+str(us)+" LS = "+str(ls))
                    rh[df['SYMBOL'][ind]]= bper


            elif(df['CLOSE'][ind] == df['OPEN'][ind] ):
                bper=0
                #per=round(((float(df['OPEN'][ind])-float(df['CLOSE'][ind]))/float(df['CLOSE'][ind]))*100,4)
                #print(df['SYMBOL'][ind] +"="+str(per))
                #print("-------------------------------------------")
                pass



    elif('Open' in df.columns):

        for ind in df.index:
            if(df['Open'][ind] < df['Close'][ind] ):
                bper=((float(df['Close'][ind])-float(df['Open'][ind]))/float(df['Close'][ind]))*100 # body percentage
                us=((float(df['High'][ind])-float(df['Close'][ind]))/float(df['Close'][ind]))*100  # Upper Shadow
                ls=((float(df['Open'][ind])-float(df['Low'][ind]))/float(df['Close'][ind]))*100  # Lower Shadow
                if(bper>=0.7 and bper<=2.3 and us<=0.8 and ls>=bper*1.8):
                   #print(df['Symbol'][ind] +"="+str(per) +" Per = "+str(per)+" US = "+str(us)+" LS = "+str(ls))
                    #bd[df['Symbol'][ind]]= bper
                    bh[ind]=df['Close'][ind]

            elif(df['Close'][ind] < df['Open'][ind] ):
                bper=((float(df['Open'][ind])-float(df['Close'][ind]))/float(df['Close'][ind]))*100 # body percentage
                us=((float(df['High'][ind])-float(df['Open'][ind]))/float(df['Close'][ind]))*100  # Upper Shadow
                ls=((float(df['Close'][ind])-float(df['Low'][ind]))/float(df['Close'][ind]))*100  # Lower Shadow
                if(bper>=0.7 and bper<=2.3 and us<=0.8 and ls>=bper*1.8):
                    #print(df['Symbol'][ind] +"="+str(per) +" Per = "+str(per)+" US = "+str(us)+" LS = "+str(ls))
                    #rd[df['Symbol'][ind]]= bper
                    rh[ind]=df['Close'][ind]

            elif(df['Close'][ind] == df['Open'][ind] ):
                bper=0
                #per=round(((float(df['Open'][ind])-float(df['Close'][ind]))/float(df['Close'][ind]))*100,4)
                #print(df['Symbol'][ind] +"="+str(per))
                #print("-------------------------------------------")
                pass

    print("BLUE HAMMER")
    print(bh)
    print("-------------------------------------------")
    print("RED HAMMER")
    print(rh)
    print("-------------------------------------------")
    #print("Blue Hammer In Downtrend")
    #for i in bh:
    #    if(isdowntrend(i)):
    #        print(i)

    #print("-------------------------------------------")
    #print("Blue Hammer In Downtrend")
    #for i in rh:
    #    if(isdowntrend(i)):
    #        print(i)

# %%
from datetime import date
import datetime
from nsepy.history import get_price_list
import yfinance as yf
import pandas as pd

#import SingleCandlesticks as sc
#from SingleCandlesticks import gethammer

# %% [markdown]
# ## Hammer ( Paper Umbrella ) one stock before n days from today

# %%
stock=input("Enter stock name : ")

print("Enter days back  to find Bullish Marubozu of given stock : ")
print("Valid days : 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max")
days=input("Enter last how many days ? : ")



## To covert the string into upper ( ex. 1mo = MO)
dstr=""
for word in days:
    if(word).isalpha():
        dstr=str(dstr)+str(word)
dstr=dstr.upper()
print(dstr)

if(dstr != 'YTD' and dstr !='MAX'):
     
    if('D' == dstr):
        d=""
        print(d)
        #d=days.split()
        numbers = []
        for word in days:
            if(word).isdigit():
                d=str(d)+str(word)
        print(d)
        

    if('MO' == dstr):
        d=""
        print(d)
        #d=days.split()
        numbers = []
        for word in days:
            if(word).isdigit():
                d=str(d)+str(word)
        print(int(d)*30)
        d=int(d)*30

    if('Y' == dstr):
        d=""
        print(d)
        #d=days.split()
        numbers = []
        for word in days:
            if(word).isdigit():
                d=str(d)+str(word)
        print(int(d)*365)
        d=int(d)*365
    print("Days = "+str(d))
# Out:
# Enter stock name : DCM
# Enter days back  to find Bullish Marubozu of given stock :
# Valid days : 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# Enter last how many days ? : 1y
# Y
#
# 365
# Days = 365

# %%
#if(days != 'ytd' and days !='YTD' and days != 'max' and days != 'MAX'):
if(dstr != 'YTD' and dstr !='MAX'):
    tstr=""
    ds=""
    if(int(d)>730):
        print("Valid intervals: [1d, 5d, 1wk, 1mo, 3mo]")
        tf=input("Enter time frame : ")
                
        ## To covert the string into lower ( ex. 1m = M)
        tstr="" #timeframestring
        ds=""   # date string
        for word in tf:
            if(word).isalpha():
                tstr=str(tstr)+str(word)
            if(word).isdigit():
                ds=str(ds)+str(word)
        tf=ds+(tstr).lower()
        print(tf) 
        
        if(tf not in ('1d', '5d', '1wk', '1mo', '3mo')):
            print("Invalid Time Frame")
            td=""
    
    
    if(int(d)>=60 and int(d)<=730):
        print("Valid intervals: [1h, 1d, 5d, 1wk, 1mo, 3mo]")
        tf=input("Enter time frame : ")
        ## To covert the string into lower ( ex. 1m = M)
        tstr="" #timeframestring
        dstr="" # date string
        for word in tf:
            if(word).isalpha():
                tstr=str(tstr)+str(word)
            if(word).isdigit():
                ds=str(ds)+str(word)
        tf=ds+(tstr).lower()
        print(tf) 
        if(tf not in ('1h', '1d', '5d', '1wk', '1mo', '3mo')):
            print("Invalid Time Frame")
            td=""
    
    if(int(d)>7 and int(d)<60):
        print("Valid intervals: ['2m', '5m', '15m', '30m', '60m', '90m',1h, 1d, 5d, 1wk, 1mo, 3mo]")
        tf=input("Enter time frame : ")
       ## To covert the string into lower ( ex. 1m = M)
        tstr="" #timeframestring
        ds="" # date string
        for word in tf:
            if(word).isalpha():
                tstr=str(tstr)+str(word)
            if(word).isdigit():
                ds=str(ds)+str(word)
        tf=ds+(tstr).lower()
        print(tf) 
        if(tf not in ('2m', '5m', '15m', '30m', '60m', '90m','1h', '1d', '5d', '1wk', '1mo', '3mo')):
            print("Invalid Time Frame")
            tf=""
            
    if(int(d)>0 and int(d)<=7):
        print("Valid intervals: ['1m',2m', '5m', '15m', '30m', '60m', '90m',1h, 1d, 5d, 1wk, 1mo, 3mo]")
        tf=input("Enter time frame : ")
       ## To covert the string into lower ( ex. 1m = M)
        tstr="" #timeframestring
        ds=""  # date sring
        for word in tf:
            if(word).isalpha():
                tstr=str(tstr)+str(word)
            if(word).isdigit():
                ds=str(ds)+str(word)
        tf=ds+(tstr).lower()
        print(tf)   
        if(tf not in ('1m','2m', '5m', '15m', '30m', '60m', '90m','1h', '1d', '5d', '1wk', '1mo', '3mo')):
            print("Invalid Time Frame")
            tf=""
# Out:
# Valid intervals: [1h, 1d, 5d, 1wk, 1mo, 3mo]
# Enter time frame : 1d
# 1d

# %%
print(days)
# Out:
# 1y

# %%
try:
    df=yf.download(tickers=stock+".NS",period=days,interval=tf)
    print(df.head())
except:
    print("Error")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2021-01-05  28.049999  29.799999  27.850000  28.549999  28.549999   53433
# 2021-01-06  29.450001  29.450001  27.799999  27.900000  27.900000   27742
# 2021-01-07  28.500000  28.700001  27.900000  28.100000  28.100000   27131
# 2021-01-08  28.000000  28.450001  27.450001  28.049999  28.049999   28394
# 2021-01-11  28.799999  28.850000  27.650000  28.350000  28.350000   38657
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2021-01-05  28.049999  29.799999  27.850000  28.549999  28.549999   53433
# 2021-01-06  29.450001  29.450001  27.799999  27.900000  27.900000   27742
# 2021-01-07  28.500000  28.700001  27.900000  28.100000  28.100000   27131
# 2021-01-08  28.000000  28.450001  27.450001  28.049999  28.049999   28394
# 2021-01-11  28.799999  28.850000  27.650000  28.350000  28.350000   38657

# %%
gethammer(df)
# Out:
# BLUE HAMMER
# {Timestamp('2021-06-07 00:00:00'): 38.75, Timestamp('2021-06-23 00:00:00'): 41.79999923706055, Timestamp('2021-08-06 00:00:00'): 59.099998474121094, Timestamp('2021-10-21 00:00:00'): 57.599998474121094, Timestamp('2021-11-15 00:00:00'): 101.9000015258789, Timestamp('2021-11-25 00:00:00'): 110.4000015258789, Timestamp('2021-12-07 00:00:00'): 123.44999694824219, Timestamp('2022-01-04 00:00:00'): 137.60000610351562}
# -------------------------------------------
# RED HAMMER
# {Timestamp('2021-03-23 00:00:00'): 24.399999618530273, Timestamp('2021-04-13 00:00:00'): 24.700000762939453, Timestamp('2021-04-27 00:00:00'): 25.049999237060547, Timestamp('2021-04-30 00:00:00'): 25.350000381469727, Timestamp('2021-06-14 00:00:00'): 41.75, Timestamp('2021-06-21 00:00:00'): 41.04999923706055, Timestamp('2021-07-15 00:00:00'): 41.349998474121094, Timestamp('2021-11-10 00:00:00'): 94.5, Timestamp('2021-11-24 00:00:00'): 105.25, Timestamp('2021-12-06 00:00:00'): 117.5999984741211}
# -------------------------------------------
